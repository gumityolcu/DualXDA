# %%
from create_train_test import *
import torch
import matplotlib.pyplot as plt

# %%
torch.manual_seed(123)
np.random.seed(123)

# %%
def visualize_tensor(t, i=0):
    plt.imshow(t[i].permute(1, 2, 0))

# %%
train_labels = create_gt_labels(20000)
test_labels = create_gt_labels(2000)
val_labels = create_gt_labels(2000)

# %%
train_data = create_tensors_from_labels(train_labels)
test_data = create_tensors_from_labels(test_labels)
val_data = create_tensors_from_labels(val_labels)

# %%
#visualize_tensor(train_data, 0)
#print(train_labels[0])

# %%
#visualize_tensor(test_data, 0)
#print(test_labels[0])

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\weckbecker\\DualView-wip\\src\\datasets\\Shapes2x2'

# %%
np.save('../../../Shapes2x2-data/Shapes2x2/train_data.npy', train_data.numpy())
np.save('../../../Shapes2x2-data/Shapes2x2/test_data.npy', test_data.numpy())
np.save('../../../Shapes2x2-data/Shapes2x2/val_data.npy', val_data.numpy())
np.save('../../../Shapes2x2-data/Shapes2x2/train_labels.npy', train_labels)
np.save('../../../Shapes2x2-data/Shapes2x2/test_labels.npy', test_labels)
np.save('../../../Shapes2x2-data/Shapes2x2/val_labels.npy', val_labels)

# %%
#train_mean = train_data.mean(dim=(0,2,3))
#train_std = train_data.std(dim=(0,2,3))

# %%
#train_mean, train_std

# %%
#torch.save(train_mean, 'shapes_data/train_mean.pt')
#torch.save(train_std, 'shapes_data/train_std.pt')

# %%
from datasets.shapes2x2 import Shapes2x2

shapes2x2 = Shapes2x2()

# %%
plt.imshow(shapes2x2[0][0].permute(1,2,0))

# %%
counter=0
for i in range(1000):
    if shapes2x2[i][1] == 0:
        counter+=1
print(counter)
# Out:
# 780

# %%
labels=np.load("shapes_data/train_labels.npy")

# %%
counter=0
for i in range(100):
    if labels[i][0:2] == 'bc' or labels[i][9:11]=='bc':
        counter+=1
print(counter)
# Out:
# 27
